# %%
from retrieve import firebase_initialize

# Run once
firebase_initialize('ai-writing-45138-f0d64e9114cc.json')

# %%
from utils import return_ai_generated_texts
df = return_ai_generated_texts()
df
# Out:
#                              55cff4a834e9060012e57407  \
# 0                                               3-pos
# 1        guidance during our last meeting our project
# 2   project outline I was wondering if you could t...
# 3   perhaps provide some additional insights or su...
# 4   product line and I'm aiming to highlight innov...
# 5   further enhance our understanding that would b...
# 6   appreciated We're aiming to make this project ...
# 7   Dr Morgan We're really excited about this proj...
# 8                                                ----
# 9                                               1-neg
# 10  I hope this email finds you well I had been wo...
# 11  anglement I understand that you must be very b...
# 12  additional study materials or resources that m...
# 13  any inconvenience this request may cause I am ...
# 14                         and support Emily Thompson
# 15                                               ----
#
# ...

# %%
df.to_csv("ai_gen_texts.csv")
